# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 731

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?q=" + weather_api_key
# Reran to remove printed Output

# %%
# Test url
city_url = url + "&q=" + 'Nashville'
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | dunedin
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 6 of Set 1 | gat
# Processing Record 7 of Set 1 | povenets
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | te anau
# Processing Record 12 of Set 1 | bhag
# Processing Record 13 of Set 1 | bandarbeyla
# Processing Record 14 of Set 1 | champerico
# Processing Record 15 of Set 1 | ladario
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | primorsk
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | lavrentiya
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | codrington
# Processing Record 26 of Set 1 | santa cruz
# Processing Record 27 of Set 1 | north bend
# Processing Record 28 of Set 1 | sudogda
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | altay
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | gamba
# Processing Record 33 of Set 1 | klaksvik
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | oyo
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | kahului
# Processing Record 42 of Set 1 | kaeo
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | sao lourenco do sul
# Processing Record 45 of Set 1 | shatrovo
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | cremona
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | stokmarknes
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | lompoc
# Processing Record 2 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 2 | kjollefjord
# Processing Record 4 of Set 2 | harbour breton
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | kungurtug
# Processing Record 9 of Set 2 | nabire
# Processing Record 10 of Set 2 | tilichiki
# Processing Record 11 of Set 2 | songea
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | dong xoai
# Processing Record 14 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | saint anthony
# Processing Record 17 of Set 2 | saryg-sep
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | biak
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | jais
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 2 | okha
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | cabra
# Processing Record 28 of Set 2 | ucluelet
# Processing Record 29 of Set 2 | erenhot
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | rikitea
# Processing Record 32 of Set 2 | grafton
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | mayumba
# Processing Record 36 of Set 2 | denpasar
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | the valley
# Processing Record 40 of Set 2 | rocky mountain house
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | bend
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | komatsu
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | abadzekhskaya
# Processing Record 1 of Set 3 | saint-augustin
# Processing Record 2 of Set 3 | kijang
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | tuy hoa
# Processing Record 5 of Set 3 | keningau
# Processing Record 6 of Set 3 | lianzhou
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | panzhihua
# Processing Record 10 of Set 3 | baracoa
# Processing Record 11 of Set 3 | longview
# Processing Record 12 of Set 3 | krasnaya polyana
# Processing Record 13 of Set 3 | kenai
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | jinka
# Processing Record 16 of Set 3 | cedar city
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | presidencia roque saenz pena
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | dingle
# Processing Record 24 of Set 3 | poum
# Processing Record 25 of Set 3 | tlacojalpan
# Processing Record 26 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 3 | udachnyy
# Processing Record 28 of Set 3 | acapulco
# Processing Record 29 of Set 3 | gardan diwal
# City not found. Skipping...
# Processing Record 30 of Set 3 | port hedland
# Processing Record 31 of Set 3 | stornoway
# Processing Record 32 of Set 3 | salalah
# Processing Record 33 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 3 | hinton
# Processing Record 36 of Set 3 | port shepstone
# Processing Record 37 of Set 3 | ulladulla
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | svetlogorsk
# Processing Record 40 of Set 3 | tual
# Processing Record 41 of Set 3 | hobyo
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | coihaique
# Processing Record 44 of Set 3 | qazvin
# Processing Record 45 of Set 3 | myitkyina
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | tawau
# Processing Record 49 of Set 3 | brownsville
# Processing Record 50 of Set 3 | mezhdurechensk
# Processing Record 1 of Set 4 | sunland park
# Processing Record 2 of Set 4 | road town
# Processing Record 3 of Set 4 | patu
# Processing Record 4 of Set 4 | tazovskiy
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | sobolevo
# Processing Record 8 of Set 4 | gediz
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | innisfail
# Processing Record 11 of Set 4 | tanta
# Processing Record 12 of Set 4 | umm lajj
# Processing Record 13 of Set 4 | faya
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | la ronge
# Processing Record 16 of Set 4 | mahibadhoo
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | sokyryany
# Processing Record 19 of Set 4 | lata
# Processing Record 20 of Set 4 | hit
# Processing Record 21 of Set 4 | palmer
# Processing Record 22 of Set 4 | payson
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | ochakiv
# Processing Record 25 of Set 4 | brodokalmak
# Processing Record 26 of Set 4 | hualmay
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | bueno brandao
# Processing Record 29 of Set 4 | ushtobe
# Processing Record 30 of Set 4 | cody
# Processing Record 31 of Set 4 | hambantota
# Processing Record 32 of Set 4 | quatre cocos
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | teguise
# Processing Record 35 of Set 4 | tera
# Processing Record 36 of Set 4 | ixtapa
# Processing Record 37 of Set 4 | mount gambier
# Processing Record 38 of Set 4 | portland
# Processing Record 39 of Set 4 | zeya
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | port elizabeth
# Processing Record 43 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 4 | puerto ayora
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 4 | mirnyy
# Processing Record 48 of Set 4 | fortuna
# Processing Record 49 of Set 4 | college
# Processing Record 50 of Set 4 | caravelas
# Processing Record 1 of Set 5 | ballina
# Processing Record 2 of Set 5 | yulara
# Processing Record 3 of Set 5 | rantepao
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | nanortalik
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | lima duarte
# Processing Record 8 of Set 5 | pacific grove
# Processing Record 9 of Set 5 | khani
# Processing Record 10 of Set 5 | kulaman
# Processing Record 11 of Set 5 | ibotirama
# Processing Record 12 of Set 5 | mogadishu
# Processing Record 13 of Set 5 | nioro
# Processing Record 14 of Set 5 | tasiilaq
# Processing Record 15 of Set 5 | chapais
# Processing Record 16 of Set 5 | seoul
# Processing Record 17 of Set 5 | andenes
# Processing Record 18 of Set 5 | kupang
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | benghazi
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | san ignacio
# Processing Record 23 of Set 5 | cihuatlan
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | labuhan
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | port augusta
# Processing Record 28 of Set 5 | port-gentil
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | sola
# Processing Record 31 of Set 5 | rhymney
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | north platte
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | hakvik
# City not found. Skipping...
# Processing Record 37 of Set 5 | oboyan
# Processing Record 38 of Set 5 | segovia
# Processing Record 39 of Set 5 | makarov
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | ende
# Processing Record 42 of Set 5 | gelemso
# Processing Record 43 of Set 5 | dubti
# Processing Record 44 of Set 5 | honningsvag
# Processing Record 45 of Set 5 | polunochnoye
# Processing Record 46 of Set 5 | zastron
# Processing Record 47 of Set 5 | maralal
# Processing Record 48 of Set 5 | sirjan
# Processing Record 49 of Set 5 | kotelnich
# Processing Record 50 of Set 5 | mayo
# Processing Record 1 of Set 6 | lodja
# Processing Record 2 of Set 6 | iqaluit
# Processing Record 3 of Set 6 | banyuwangi
# Processing Record 4 of Set 6 | yuci
# Processing Record 5 of Set 6 | saskylakh
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | sao gabriel da cachoeira
# Processing Record 8 of Set 6 | rocha
# Processing Record 9 of Set 6 | lady frere
# Processing Record 10 of Set 6 | taft
# Processing Record 11 of Set 6 | mizan teferi
# Processing Record 12 of Set 6 | bilma
# Processing Record 13 of Set 6 | krasnyy chikoy
# Processing Record 14 of Set 6 | bousse
# Processing Record 15 of Set 6 | buala
# Processing Record 16 of Set 6 | yola
# Processing Record 17 of Set 6 | xining
# Processing Record 18 of Set 6 | sisimiut
# Processing Record 19 of Set 6 | kousseri
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | kerzhenets
# City not found. Skipping...
# Processing Record 22 of Set 6 | kununurra
# Processing Record 23 of Set 6 | salamanca
# Processing Record 24 of Set 6 | gorontalo
# Processing Record 25 of Set 6 | isangel
# Processing Record 26 of Set 6 | qaqortoq
# Processing Record 27 of Set 6 | taber
# Processing Record 28 of Set 6 | anadyr
# Processing Record 29 of Set 6 | bonavista
# Processing Record 30 of Set 6 | princeton
# Processing Record 31 of Set 6 | sladkovo
# Processing Record 32 of Set 6 | tarko-sale
# Processing Record 33 of Set 6 | itaituba
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | los cedrales
# Processing Record 36 of Set 6 | uglovskoye
# Processing Record 37 of Set 6 | banjar
# Processing Record 38 of Set 6 | dubbo
# Processing Record 39 of Set 6 | chara
# Processing Record 40 of Set 6 | ures
# Processing Record 41 of Set 6 | mount isa
# Processing Record 42 of Set 6 | panyutyne
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | upington
# Processing Record 45 of Set 6 | vardo
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | cabo san lucas
# Processing Record 48 of Set 6 | cascais
# Processing Record 49 of Set 6 | soskovo
# Processing Record 50 of Set 6 | eyl
# Processing Record 1 of Set 7 | pueblo nuevo
# Processing Record 2 of Set 7 | zaragoza
# Processing Record 3 of Set 7 | torbay
# Processing Record 4 of Set 7 | ancud
# Processing Record 5 of Set 7 | umea
# Processing Record 6 of Set 7 | rawson
# Processing Record 7 of Set 7 | tahoua
# Processing Record 8 of Set 7 | kismayo
# Processing Record 9 of Set 7 | livingston
# Processing Record 10 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | tateyama
# Processing Record 13 of Set 7 | el corozal
# Processing Record 14 of Set 7 | xuddur
# Processing Record 15 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 7 | guerrero negro
# Processing Record 17 of Set 7 | zhanaozen
# Processing Record 18 of Set 7 | la libertad
# Processing Record 19 of Set 7 | goderich
# Processing Record 20 of Set 7 | komono
# Processing Record 21 of Set 7 | prince rupert
# Processing Record 22 of Set 7 | kloulklubed
# Processing Record 23 of Set 7 | valle hermoso
# Processing Record 24 of Set 7 | matagami
# Processing Record 25 of Set 7 | itarema
# Processing Record 26 of Set 7 | bilibino
# Processing Record 27 of Set 7 | bethel
# Processing Record 28 of Set 7 | nizhniy baskunchak
# Processing Record 29 of Set 7 | kodiak
# Processing Record 30 of Set 7 | redding
# Processing Record 31 of Set 7 | vadso
# Processing Record 32 of Set 7 | oakdale
# Processing Record 33 of Set 7 | isla mujeres
# Processing Record 34 of Set 7 | west wendover
# Processing Record 35 of Set 7 | libenge
# Processing Record 36 of Set 7 | oswego
# Processing Record 37 of Set 7 | sakaiminato
# Processing Record 38 of Set 7 | camacha
# Processing Record 39 of Set 7 | maraba
# Processing Record 40 of Set 7 | ambunti
# Processing Record 41 of Set 7 | leningradskiy
# Processing Record 42 of Set 7 | hasaki
# Processing Record 43 of Set 7 | aykhal
# Processing Record 44 of Set 7 | sheridan
# Processing Record 45 of Set 7 | karratha
# Processing Record 46 of Set 7 | astorga
# Processing Record 47 of Set 7 | samana
# Processing Record 48 of Set 7 | kudahuvadhoo
# Processing Record 49 of Set 7 | gornyak
# Processing Record 50 of Set 7 | diamantino
# Processing Record 1 of Set 8 | sorland
# Processing Record 2 of Set 8 | cabedelo
# Processing Record 3 of Set 8 | tarakan
# Processing Record 4 of Set 8 | batemans bay
# Processing Record 5 of Set 8 | adrar
# Processing Record 6 of Set 8 | mayya
# Processing Record 7 of Set 8 | port hardy
# Processing Record 8 of Set 8 | santa maria del oro
# Processing Record 9 of Set 8 | margate
# Processing Record 10 of Set 8 | yeppoon
# Processing Record 11 of Set 8 | ust-kuyga
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | avera
# Processing Record 14 of Set 8 | melfi
# Processing Record 15 of Set 8 | sao joao da barra
# Processing Record 16 of Set 8 | djibo
# Processing Record 17 of Set 8 | olafsvik
# Processing Record 18 of Set 8 | antofagasta
# Processing Record 19 of Set 8 | ahipara
# Processing Record 20 of Set 8 | lagoa
# Processing Record 21 of Set 8 | palana
# Processing Record 22 of Set 8 | roros
# Processing Record 23 of Set 8 | muncar
# Processing Record 24 of Set 8 | deputatskiy
# Processing Record 25 of Set 8 | jiangkou
# Processing Record 26 of Set 8 | ribeira grande
# Processing Record 27 of Set 8 | ust-tsilma
# Processing Record 28 of Set 8 | marawi
# Processing Record 29 of Set 8 | bathsheba
# Processing Record 30 of Set 8 | constantine
# Processing Record 31 of Set 8 | ulu-telyak
# Processing Record 32 of Set 8 | fort-shevchenko
# Processing Record 33 of Set 8 | tucuman
# Processing Record 34 of Set 8 | banda aceh
# Processing Record 35 of Set 8 | ambilobe
# Processing Record 36 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 8 | axim
# Processing Record 38 of Set 8 | tumpat
# Processing Record 39 of Set 8 | antigonish
# Processing Record 40 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | kamaishi
# Processing Record 42 of Set 8 | ayagoz
# Processing Record 43 of Set 8 | waingapu
# Processing Record 44 of Set 8 | westport
# Processing Record 45 of Set 8 | luanda
# Processing Record 46 of Set 8 | oriximina
# Processing Record 47 of Set 8 | ponta delgada
# Processing Record 48 of Set 8 | canberra
# Processing Record 49 of Set 8 | manta
# Processing Record 50 of Set 8 | takoradi
# Processing Record 1 of Set 9 | san quintin
# Processing Record 2 of Set 9 | mana
# Processing Record 3 of Set 9 | san policarpo
# Processing Record 4 of Set 9 | karousades
# City not found. Skipping...
# Processing Record 5 of Set 9 | wanning
# Processing Record 6 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 9 | canutama
# Processing Record 8 of Set 9 | taoudenni
# Processing Record 9 of Set 9 | itacoatiara
# Processing Record 10 of Set 9 | kuytun
# Processing Record 11 of Set 9 | bundaberg
# Processing Record 12 of Set 9 | terrasini
# Processing Record 13 of Set 9 | beisfjord
# Processing Record 14 of Set 9 | dryden
# Processing Record 15 of Set 9 | lephepe
# City not found. Skipping...
# Processing Record 16 of Set 9 | half moon bay
# Processing Record 17 of Set 9 | balaka
# Processing Record 18 of Set 9 | zhangjiakou
# Processing Record 19 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 9 | koygorodok
# Processing Record 21 of Set 9 | neuquen
# Processing Record 22 of Set 9 | antalaha
# Processing Record 23 of Set 9 | simi
# Processing Record 24 of Set 9 | siderno
# Processing Record 25 of Set 9 | vanimo
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | russell
# Processing Record 28 of Set 9 | alofi
# Processing Record 29 of Set 9 | passo de camaragibe
# Processing Record 30 of Set 9 | high level
# Processing Record 31 of Set 9 | tautira
# Processing Record 32 of Set 9 | richards bay
# Processing Record 33 of Set 9 | taybad
# Processing Record 34 of Set 9 | vestmannaeyjar
# Processing Record 35 of Set 9 | meulaboh
# Processing Record 36 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | winnemucca
# Processing Record 39 of Set 9 | sant pere de ribes
# Processing Record 40 of Set 9 | sao felix do xingu
# Processing Record 41 of Set 9 | wamba
# Processing Record 42 of Set 9 | jaisalmer
# Processing Record 43 of Set 9 | nuuk
# Processing Record 44 of Set 9 | gigmoto
# Processing Record 45 of Set 9 | male
# Processing Record 46 of Set 9 | bikin
# Processing Record 47 of Set 9 | angra
# City not found. Skipping...
# Processing Record 48 of Set 9 | puerto narino
# Processing Record 49 of Set 9 | elmadag
# Processing Record 50 of Set 9 | bairiki
# Processing Record 1 of Set 10 | kruszwica
# Processing Record 2 of Set 10 | alice town
# Processing Record 3 of Set 10 | komsomolskiy
# Processing Record 4 of Set 10 | jiayuguan
# Processing Record 5 of Set 10 | kyren
# Processing Record 6 of Set 10 | maningrida
# Processing Record 7 of Set 10 | san cristobal
# Processing Record 8 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 11 of Set 10 | quang ngai
# Processing Record 12 of Set 10 | hami
# Processing Record 13 of Set 10 | reiskirchen
# Processing Record 14 of Set 10 | suleja
# Processing Record 15 of Set 10 | paamiut
# Processing Record 16 of Set 10 | flinders
# Processing Record 17 of Set 10 | black river
# Processing Record 18 of Set 10 | birin
# Processing Record 19 of Set 10 | warrington
# Processing Record 20 of Set 10 | berdigestyakh
# Processing Record 21 of Set 10 | tambacounda
# Processing Record 22 of Set 10 | saint-leu
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | brae
# Processing Record 25 of Set 10 | aberdeen
# Processing Record 26 of Set 10 | port lincoln
# Processing Record 27 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 10 | conceicao da barra
# Processing Record 29 of Set 10 | fort nelson
# Processing Record 30 of Set 10 | ashland
# Processing Record 31 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 10 | gafanha da encarnacao
# Processing Record 33 of Set 10 | linhares
# Processing Record 34 of Set 10 | nizwa
# Processing Record 35 of Set 10 | plouzane
# Processing Record 36 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 10 | san pedro
# Processing Record 38 of Set 10 | neiafu
# Processing Record 39 of Set 10 | katobu
# Processing Record 40 of Set 10 | eureka
# Processing Record 41 of Set 10 | asfi
# Processing Record 42 of Set 10 | svodin
# Processing Record 43 of Set 10 | kinna
# Processing Record 44 of Set 10 | igurubi
# Processing Record 45 of Set 10 | sioux lookout
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | hay river
# Processing Record 48 of Set 10 | machinga
# Processing Record 49 of Set 10 | camana
# Processing Record 50 of Set 10 | jumla
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | talavera
# Processing Record 3 of Set 11 | mao
# Processing Record 4 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 5 of Set 11 | katsuura
# Processing Record 6 of Set 11 | porto belo
# Processing Record 7 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 11 | garissa
# Processing Record 9 of Set 11 | mezen
# Processing Record 10 of Set 11 | nelidovo
# Processing Record 11 of Set 11 | peniche
# Processing Record 12 of Set 11 | bollnas
# Processing Record 13 of Set 11 | muzhi
# Processing Record 14 of Set 11 | jalu
# Processing Record 15 of Set 11 | roma
# Processing Record 16 of Set 11 | kysyl-syr
# Processing Record 17 of Set 11 | fukue
# Processing Record 18 of Set 11 | kidal
# Processing Record 19 of Set 11 | broken hill
# Processing Record 20 of Set 11 | yumen
# Processing Record 21 of Set 11 | saint-louis
# Processing Record 22 of Set 11 | roald
# Processing Record 23 of Set 11 | ginda
# Processing Record 24 of Set 11 | cacu
# Processing Record 25 of Set 11 | riyadh
# Processing Record 26 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 11 | surt
# Processing Record 29 of Set 11 | kamien pomorski
# Processing Record 30 of Set 11 | candido mendes
# Processing Record 31 of Set 11 | santiago
# Processing Record 32 of Set 11 | saint george
# Processing Record 33 of Set 11 | kita
# Processing Record 34 of Set 11 | padang
# Processing Record 35 of Set 11 | effingham
# Processing Record 36 of Set 11 | luderitz
# Processing Record 37 of Set 11 | maceio
# Processing Record 38 of Set 11 | oranjemund
# Processing Record 39 of Set 11 | benguela
# Processing Record 40 of Set 11 | bambanglipuro
# Processing Record 41 of Set 11 | vila velha
# Processing Record 42 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 11 | strezhevoy
# Processing Record 44 of Set 11 | majene
# Processing Record 45 of Set 11 | angoche
# Processing Record 46 of Set 11 | severo-yeniseyskiy
# Processing Record 47 of Set 11 | karad
# Processing Record 48 of Set 11 | kamenka
# Processing Record 49 of Set 11 | burica
# City not found. Skipping...
# Processing Record 50 of Set 11 | pangody
# Processing Record 1 of Set 12 | leh
# Processing Record 2 of Set 12 | ovalle
# Processing Record 3 of Set 12 | beringovskiy
# Processing Record 4 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 12 | nha trang
# Processing Record 6 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 12 | sindor
# Processing Record 8 of Set 12 | puerto carreno
# Processing Record 9 of Set 12 | havoysund
# Processing Record 10 of Set 12 | minden
# Processing Record 11 of Set 12 | fare
# Processing Record 12 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 12 | praya
# Processing Record 14 of Set 12 | ingham
# Processing Record 15 of Set 12 | port blair
# Processing Record 16 of Set 12 | puro
# Processing Record 17 of Set 12 | melfort
# Processing Record 18 of Set 12 | dobris
# Processing Record 19 of Set 12 | yuzhno-kurilsk
# Processing Record 20 of Set 12 | camacupa
# Processing Record 21 of Set 12 | outjo
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | bama
# Processing Record 24 of Set 12 | opuwo
# Processing Record 25 of Set 12 | vila
# Processing Record 26 of Set 12 | kez
# Processing Record 27 of Set 12 | mmathubudukwane
# Processing Record 28 of Set 12 | novosergiyevka
# Processing Record 29 of Set 12 | egvekinot
# Processing Record 30 of Set 12 | kiama
# Processing Record 31 of Set 12 | aswan
# Processing Record 32 of Set 12 | la romana
# Processing Record 33 of Set 12 | ibra
# Processing Record 34 of Set 12 | cockburn town
# Processing Record 35 of Set 12 | colac
# Processing Record 36 of Set 12 | barranca
# Processing Record 37 of Set 12 | paciran
# Processing Record 38 of Set 12 | viedma
# Processing Record 39 of Set 12 | tonj
# Processing Record 40 of Set 12 | jurm
# Processing Record 41 of Set 12 | wanaka
# Processing Record 42 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 12 | praia da vitoria
# Processing Record 44 of Set 12 | watertown
# Processing Record 45 of Set 12 | broome
# Processing Record 46 of Set 12 | chumikan
# Processing Record 47 of Set 12 | los angeles
# Processing Record 48 of Set 12 | boende
# Processing Record 49 of Set 12 | pisco
# Processing Record 50 of Set 12 | trincomalee
# Processing Record 1 of Set 13 | tessalit
# Processing Record 2 of Set 13 | pleasanton
# Processing Record 3 of Set 13 | isabela
# Processing Record 4 of Set 13 | shihezi
# Processing Record 5 of Set 13 | urumqi
# Processing Record 6 of Set 13 | poronaysk
# Processing Record 7 of Set 13 | shieli
# Processing Record 8 of Set 13 | shu
# Processing Record 9 of Set 13 | nguru
# Processing Record 10 of Set 13 | cooma
# Processing Record 11 of Set 13 | wuhu
# Processing Record 12 of Set 13 | marondera
# Processing Record 13 of Set 13 | nanakuli
# Processing Record 14 of Set 13 | vicksburg
# Processing Record 15 of Set 13 | veracruz
# Processing Record 16 of Set 13 | marsa matruh
# Processing Record 17 of Set 13 | tunghsiao
# City not found. Skipping...
# Processing Record 18 of Set 13 | katherine
# Processing Record 19 of Set 13 | pochutla
# Processing Record 20 of Set 13 | vila franca do campo
# Processing Record 21 of Set 13 | lianran
# Processing Record 22 of Set 13 | ust-kulom
# Processing Record 23 of Set 13 | yar-sale
# Processing Record 24 of Set 13 | qorveh
# Processing Record 25 of Set 13 | alice springs
# Processing Record 26 of Set 13 | lahan
# Processing Record 27 of Set 13 | terme
# Processing Record 28 of Set 13 | lebanon
# Processing Record 29 of Set 13 | bafoulabe
# Processing Record 30 of Set 13 | kajaani
# Processing Record 31 of Set 13 | changli
# Processing Record 32 of Set 13 | limbe
# Processing Record 33 of Set 13 | kavieng
# Processing Record 34 of Set 13 | dire
# Processing Record 35 of Set 13 | muros
# Processing Record 36 of Set 13 | harper
# Processing Record 37 of Set 13 | fatehabad
# Processing Record 38 of Set 13 | weligama
# Processing Record 39 of Set 13 | tura
# Processing Record 40 of Set 13 | geraldton
# Processing Record 41 of Set 13 | ajaccio
# Processing Record 42 of Set 13 | sengiley
# Processing Record 43 of Set 13 | saquarema
# Processing Record 44 of Set 13 | ulundi
# Processing Record 45 of Set 13 | shetpe
# Processing Record 46 of Set 13 | kollumerland
# City not found. Skipping...
# Processing Record 47 of Set 13 | rach gia
# Processing Record 48 of Set 13 | calvia
# Processing Record 49 of Set 13 | acari
# Processing Record 50 of Set 13 | castrop-rauxel
# Processing Record 1 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 14 | berbera
# Processing Record 3 of Set 14 | baykit
# Processing Record 4 of Set 14 | maldonado
# Processing Record 5 of Set 14 | kuito
# Processing Record 6 of Set 14 | key largo
# Processing Record 7 of Set 14 | shingu
# Processing Record 8 of Set 14 | senanga
# Processing Record 9 of Set 14 | itoman
# Processing Record 10 of Set 14 | dolgoye
# Processing Record 11 of Set 14 | inhambane
# Processing Record 12 of Set 14 | tabou
# Processing Record 13 of Set 14 | kovdor
# Processing Record 14 of Set 14 | santa maria
# Processing Record 15 of Set 14 | canora
# Processing Record 16 of Set 14 | belmonte
# Processing Record 17 of Set 14 | byron bay
# Processing Record 18 of Set 14 | heihe
# Processing Record 19 of Set 14 | lasa
# Processing Record 20 of Set 14 | hervey bay
# Processing Record 21 of Set 14 | umba
# Processing Record 22 of Set 14 | tlaxiaco
# City not found. Skipping...
# Processing Record 23 of Set 14 | rye
# Processing Record 24 of Set 14 | piacabucu
# Processing Record 25 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 14 | santiago de cao
# Processing Record 27 of Set 14 | dongargaon
# Processing Record 28 of Set 14 | isfana
# Processing Record 29 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 14 | talnakh
# Processing Record 31 of Set 14 | vestmanna
# Processing Record 32 of Set 14 | ardakan
# Processing Record 33 of Set 14 | yongchang
# Processing Record 34 of Set 14 | kintinku
# Processing Record 35 of Set 14 | soloneshnoye
# Processing Record 36 of Set 14 | nakusp
# Processing Record 37 of Set 14 | buzdyak
# Processing Record 38 of Set 14 | conceicao do coite
# Processing Record 39 of Set 14 | lake city
# Processing Record 40 of Set 14 | pierre
# Processing Record 41 of Set 14 | araouane
# Processing Record 42 of Set 14 | halifax
# Processing Record 43 of Set 14 | patitirion
# Processing Record 44 of Set 14 | den helder
# Processing Record 45 of Set 14 | ahmadpur east
# Processing Record 46 of Set 14 | qurayyat
# Processing Record 47 of Set 14 | kariba
# Processing Record 48 of Set 14 | los llanos de aridane
# Processing Record 49 of Set 14 | rancho veloz
# Processing Record 50 of Set 14 | ruwi
# Processing Record 1 of Set 15 | valladolid
# Processing Record 2 of Set 15 | shache
# Processing Record 3 of Set 15 | peque
# Processing Record 4 of Set 15 | kodinsk
# Processing Record 5 of Set 15 | bara
# Processing Record 6 of Set 15 | shellbrook
# Processing Record 7 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 15 | alekseyevskaya
# Processing Record 9 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 11 of Set 15 | vao
# Processing Record 12 of Set 15 | villazon
# Processing Record 13 of Set 15 | galle
# Processing Record 14 of Set 15 | kutum
# Processing Record 15 of Set 15 | lakes entrance
# Processing Record 16 of Set 15 | yokadouma
# Processing Record 17 of Set 15 | guanambi
# Processing Record 18 of Set 15 | danilovka
# Processing Record 19 of Set 15 | senno
# Processing Record 20 of Set 15 | grindavik
# Processing Record 21 of Set 15 | bucerias
# Processing Record 22 of Set 15 | carupano
# Processing Record 23 of Set 15 | shambu
# Processing Record 24 of Set 15 | gizo
# Processing Record 25 of Set 15 | monforte de lemos
# Processing Record 26 of Set 15 | ola
# Processing Record 27 of Set 15 | hanmer springs
# Processing Record 28 of Set 15 | okhotsk
# Processing Record 29 of Set 15 | willmar
# Processing Record 30 of Set 15 | sumbe
# Processing Record 31 of Set 15 | port-cartier
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus -34.4187   19.2345     52.81        73          97
# 1         Kapaa  22.0752 -159.3190     84.18        71          75
# 2       Dunedin -45.8742  170.5036     38.34        85         100
# 3           Gat  31.6100   34.7642     74.39       100           0
# 4      Povenets  62.8487   34.8262     45.77        95         100
# 5  Punta Arenas -53.1500  -70.9167     46.51        71          75
# 6    Butaritari   3.0707  172.7902     81.88        75          30
# 7       Te Anau -45.4167  167.7167     38.98        75          75
# 8          Bhag  29.0415   67.8239     83.37        37           0
# 9   Bandarbeyla   9.4942   50.8122     76.05        86         100
#
#    Wind Speed Country Weather Description
# 0        4.27      ZA     overcast clouds
# 1       14.97      US       broken clouds
# 2       20.51      NZ     overcast clouds
# 3        0.60      IL           clear sky
# 4        6.55      RU     overcast clouds
# 5       11.50      CL       broken clouds
# 6       18.14      KI          light rain
# 7       10.49      NZ       broken clouds
# 8        4.25      PK           clear sky
# 9       19.33      SO     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
#update_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
#city_data_df = city_data_df[update_column_order]
# Display sample data
#city_data_df.head(10)

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
